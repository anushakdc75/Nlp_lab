# %%
import re

# %%
text = """
Hello, contact me at student123@gmail.com.
Visit https://www.example.com for more info.
<p>This is a sample HTML paragraph.</p>
My phone number is 9876543210.
Price is 5000 rupees!!!
"""

print("Original Text:")
print(text)
print("-" * 50)


text = re.sub(r'\S+@\S+', '', text)


text = re.sub(r'https?://\S+|www\.\S+', '', text)


text = re.sub(r'<.*?>', '', text)


text = re.sub(r'\d+', '', text)

text = re.sub(r'[^A-Za-z\s]', '', text)

text = re.sub(r'\s+', ' ', text).strip()


print("Cleaned Text:")
print(text)
# Out:
# Original Text:
#
# Hello, contact me at student123@gmail.com.
# Visit https://www.example.com for more info.
# <p>This is a sample HTML paragraph.</p>
# My phone number is 9876543210.
# Price is 5000 rupees!!!
#
# --------------------------------------------------
# Cleaned Text:
# Hello contact me at Visit for more info This is a sample HTML paragraph My phone number is Price is rupees
